# %%
import pandas as pd

# %%
import klib

# %%
xlsx = pd.ExcelFile('sample_-_superstore.xls')

# %%
df = pd.read_excel(xlsx, "Orders")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
klib.missingval_plot(df)
# Out:
# No missing values found in the dataset.

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df_cleaned = klib.data_cleaning(df)
# Out:
# Shape of cleaned data: (9994, 20)Remaining NAs: 0
#
# Changes:
# Dropped rows: 0
#      of which 0 duplicates. (Rows: [])
# Dropped columns: 1
#      of which 1 single valued.     Columns: ['country']
# Dropped missing values: 0
# Reduced memory by at least: 0.72 MB (-45.0%)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         9994 non-null   int16
#  1   order_id       9994 non-null   string
#  2   order_date     9994 non-null   datetime64[ns]
#  3   ship_date      9994 non-null   datetime64[ns]
#  4   ship_mode      9994 non-null   category
#  5   customer_id    9994 non-null   string
#  6   customer_name  9994 non-null   string
#  7   segment        9994 non-null   category
#  8   city           9994 non-null   string
#  9   state          9994 non-null   category
#  10  postal_code    9994 non-null   int32
#  11  region         9994 non-null   category
#  12  product_id     9994 non-null   string
#  13  category       9994 non-null   category
#  14  sub_category   9994 non-null   category
#  15  product_name   9994 non-null   string
#  16  sales          9994 non-null   Float32
# ...

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df_cleaned.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         9994 non-null   int16
#  1   order_id       9994 non-null   string
#  2   order_date     9994 non-null   datetime64[ns]
#  3   ship_date      9994 non-null   datetime64[ns]
#  4   ship_mode      9994 non-null   category
#  5   customer_id    9994 non-null   string
#  6   customer_name  9994 non-null   string
#  7   segment        9994 non-null   category
#  8   city           9994 non-null   string
#  9   state          9994 non-null   category
#  10  postal_code    9994 non-null   int32
#  11  region         9994 non-null   category
#  12  product_id     9994 non-null   string
#  13  category       9994 non-null   category
#  14  sub_category   9994 non-null   category
#  15  product_name   9994 non-null   string
#  16  sales          9994 non-null   Float32
# ...

# %%
df_cleaned.head()
# Out:
#    row_id        order_id order_date  ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      customer_name    segment             city       state  postal_code  \
# 0      Claire Gute   Consumer        Henderson    Kentucky        42420
# 1      Claire Gute   Consumer        Henderson    Kentucky        42420
# 2  Darrin Van Huff  Corporate      Los Angeles  California        90036
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
#
#   region       product_id         category sub_category  \
# ...

# %%
df_profit = df_cleaned[["state", "profit"]].copy()

# %%
df_profit.shape
# Out:
# (9994, 2)

# %%
df_profit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   state   9994 non-null   category
#  1   profit  9994 non-null   Float32
# dtypes: Float32(1), category(1)
# memory usage: 60.1 KB

# %%
df_profit.head(50)
# Out:
#              state       profit
# 0         Kentucky    41.913601
# 1         Kentucky   219.582001
# 2       California       6.8714
# 3          Florida  -383.031006
# 4          Florida       2.5164
# 5       California      14.1694
# 6       California       1.9656
# 7       California    90.715202
# 8       California       5.7825
# 9       California    34.470001
# 10      California    85.309196
# 11      California    68.356796
# 12  North Carolina       5.4432
# 13      Washington   132.592194
# 14           Texas  -123.858002
# 15           Texas       -3.816
# 16       Wisconsin      13.3176
# 17            Utah         9.99
# 18      California       2.4824
# 19      California       16.011
# 20      California        7.384
# 21        Nebraska       5.0596
# 22        Nebraska      15.6884
# 23    Pennsylvania      -1.0196
# 24            Utah   240.264893
# 25      California       4.2224
# 26      California      11.7741
# 27    Pennsylvania -1665.052246
# ...

# %%
df_total_profit_by_state = df_profit.groupby("state").sum().reset_index()

# %%
df_total_profit_by_state.head(50)
# Out:
#                    state        profit
# 0                Alabama   5786.825195
# 1                Arizona  -3427.924561
# 2               Arkansas   4008.687012
# 3             California  76381.390625
# 4               Colorado   -6527.85791
# 5            Connecticut   3511.491699
# 6               Delaware      9977.375
# 7   District of Columbia   1059.589233
# 8                Florida  -3399.301514
# 9                Georgia  16250.042969
# 10                 Idaho    826.723083
# 11              Illinois -12607.886719
# 12               Indiana  18382.935547
# 13                  Iowa    1183.81189
# 14                Kansas    836.443481
# 15              Kentucky  11199.696289
# 16             Louisiana   2196.102295
# 17                 Maine    454.486206
# 18              Maryland   7031.178711
# 19         Massachusetts   6785.501465
# 20              Michigan    24463.1875
# 21             Minnesota    10823.1875
# 22           Mississippi   3172.976074
# ...

# %%
df_total_profit_by_state ["rank"]= df_total_profit_by_state["profit"].rank(ascending=False)

# %%
df_total_profit_by_state.shape
# Out:
# (49, 3)

# %%
df_total_profit_by_state.head(50)
# Out:
#                    state        profit  rank
# 0                Alabama   5786.825195  17.0
# 1                Arizona  -3427.924561  42.0
# 2               Arkansas   4008.687012  19.0
# 3             California  76381.390625   1.0
# 4               Colorado   -6527.85791  44.0
# 5            Connecticut   3511.491699  20.0
# 6               Delaware      9977.375  10.0
# 7   District of Columbia   1059.589233  32.0
# 8                Florida  -3399.301514  41.0
# 9                Georgia  16250.042969   7.0
# 10                 Idaho    826.723083  34.0
# 11              Illinois -12607.886719  46.0
# 12               Indiana  18382.935547   6.0
# 13                  Iowa    1183.81189  30.0
# 14                Kansas    836.443481  33.0
# 15              Kentucky  11199.696289   8.0
# 16             Louisiana   2196.102295  25.0
# 17                 Maine    454.486206  35.0
# 18              Maryland   7031.178711  14.0
# 19         Massachusetts   6785.501465  15.0
# ...

# %%
df_sorted = df_total_profit_by_state.sort_values("rank", ascending=True)

# %%
df_sorted.shape
# Out:
# (49, 3)

# %%
df_sorted.head(50)
# Out:
#                    state        profit  rank
# 3             California  76381.390625   1.0
# 30              New York  74038.546875   2.0
# 45            Washington  33402.652344   3.0
# 20              Michigan    24463.1875   4.0
# 44              Virginia  18597.951172   5.0
# 12               Indiana  18382.935547   6.0
# 9                Georgia  16250.042969   7.0
# 15              Kentucky  11199.696289   8.0
# 21             Minnesota    10823.1875   9.0
# 6               Delaware      9977.375  10.0
# 28            New Jersey   9772.914062  11.0
# 47             Wisconsin   8401.800781  12.0
# 37          Rhode Island   7285.629395  13.0
# 18              Maryland   7031.178711  14.0
# 19         Massachusetts   6785.501465  15.0
# 23              Missouri   6436.210449  16.0
# 0                Alabama   5786.825195  17.0
# 34              Oklahoma   4853.956055  18.0
# 2               Arkansas   4008.687012  19.0
# 5            Connecticut   3511.491699  20.0
# ...

# %%
df_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 3 to 41
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   state   49 non-null     category
#  1   profit  49 non-null     Float32
#  2   rank    49 non-null     float64
# dtypes: Float32(1), category(1), float64(1)
# memory usage: 2.5 KB

# %%
df_roundup_profit = df_sorted.copy()

# %%
df_roundup_profit.head(50)
# Out:
#                    state        profit  rank
# 3             California  76381.390625   1.0
# 30              New York  74038.546875   2.0
# 45            Washington  33402.652344   3.0
# 20              Michigan    24463.1875   4.0
# 44              Virginia  18597.951172   5.0
# 12               Indiana  18382.935547   6.0
# 9                Georgia  16250.042969   7.0
# 15              Kentucky  11199.696289   8.0
# 21             Minnesota    10823.1875   9.0
# 6               Delaware      9977.375  10.0
# 28            New Jersey   9772.914062  11.0
# 47             Wisconsin   8401.800781  12.0
# 37          Rhode Island   7285.629395  13.0
# 18              Maryland   7031.178711  14.0
# 19         Massachusetts   6785.501465  15.0
# 23              Missouri   6436.210449  16.0
# 0                Alabama   5786.825195  17.0
# 34              Oklahoma   4853.956055  18.0
# 2               Arkansas   4008.687012  19.0
# 5            Connecticut   3511.491699  20.0
# ...

# %%
import numpy as np

# %%
df_roundup_profit['profit'] = df_roundup_profit['profit'].apply(np.ceil).astype(int)

# %%
df_roundup_profit.head(50)
# Out:
#                    state  profit  rank
# 3             California   76382   1.0
# 30              New York   74039   2.0
# 45            Washington   33403   3.0
# 20              Michigan   24464   4.0
# 44              Virginia   18598   5.0
# 12               Indiana   18383   6.0
# 9                Georgia   16251   7.0
# 15              Kentucky   11200   8.0
# 21             Minnesota   10824   9.0
# 6               Delaware    9978  10.0
# 28            New Jersey    9773  11.0
# 47             Wisconsin    8402  12.0
# 37          Rhode Island    7286  13.0
# 18              Maryland    7032  14.0
# 19         Massachusetts    6786  15.0
# 23              Missouri    6437  16.0
# 0                Alabama    5787  17.0
# 34              Oklahoma    4854  18.0
# 2               Arkansas    4009  19.0
# 5            Connecticut    3512  20.0
# 26                Nevada    3317  21.0
# 22           Mississippi    3173  22.0
# 42                  Utah    2547  23.0
# ...

# %%
df_top_ten_states_by_profits = df_roundup_profit.query("rank<=10")

# %%
df_top_ten_states_by_profits.head(11)
# Out:
#          state  profit  rank
# 3   California   76382   1.0
# 30    New York   74039   2.0
# 45  Washington   33403   3.0
# 20    Michigan   24464   4.0
# 44    Virginia   18598   5.0
# 12     Indiana   18383   6.0
# 9      Georgia   16251   7.0
# 15    Kentucky   11200   8.0
# 21   Minnesota   10824   9.0
# 6     Delaware    9978  10.0

# %%
df_top_ten_states_by_profits["profit"].describe()
# Out:
# count       10.000000
# mean     29352.200000
# std      25176.685546
# min       9978.000000
# 25%      12462.750000
# 50%      18490.500000
# 75%      31168.250000
# max      76382.000000
# Name: profit, dtype: float64

# %%
df_top_ten_states_by_profits.to_csv('topTenStatesByProfits.csv', index=False)
